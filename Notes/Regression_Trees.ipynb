# %% [markdown]
# ## Data Preprocessing

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Import the bike sharing dataset from UC Irvine.

# %%
from ucimlrepo import fetch_ucirepo

# fetch bike share dataset
bike_data = fetch_ucirepo(id=275)

# initialize dataframes (as pandas dataframes)
X = bike_data.data.features
y = bike_data.data.targets

# metadata
# print(bike_data.metadata)

# variable information
print(bike_data.variables)
# Out:
#           name     role         type demographic  \
# 0      instant       ID      Integer        None
# 1       dteday  Feature         Date        None
# 2       season  Feature  Categorical        None
# 3           yr  Feature  Categorical        None
# 4         mnth  Feature  Categorical        None
# 5           hr  Feature  Categorical        None
# 6      holiday  Feature       Binary        None
# 7      weekday  Feature  Categorical        None
# 8   workingday  Feature       Binary        None
# 9   weathersit  Feature  Categorical        None
# 10        temp  Feature   Continuous        None
# 11       atemp  Feature   Continuous        None
# 12         hum  Feature   Continuous        None
# 13   windspeed  Feature   Continuous        None
# 14      casual    Other      Integer        None
# 15  registered    Other      Integer        None
# 16         cnt   Target      Integer        None
#
#                                           description units missing_values
# 0                                        record index  None             no
# 1                                                date  None             no
# 2                1:winter, 2:spring, 3:summer, 4:fall  None             no
# 3                             year (0: 2011, 1: 2012)  None             no
# 4                                     month (1 to 12)  None             no
# 5                                      hour (0 to 23)  None             no
# 6   weather day is holiday or not (extracted from ...  None             no
# 7                                     day of the week  None             no
# 8   if day is neither weekend nor holiday is 1, ot...  None             no
# 9   - 1: Clear, Few clouds, Partly cloudy, Partly ...  None             no
# 10  Normalized temperature in Celsius. The values ...     C             no
# 11  Normalized feeling temperature in Celsius. The...     C             no
# 12  Normalized humidity. The values are divided to...  None             no
# 13  Normalized wind speed. The values are divided ...  None             no
# 14                              count of casual users  None             no
# 15                          count of registered users  None             no
# 16  count of total rental bikes including both cas...  None             no

# %% [markdown]
# ## Regression Tree on Factor Features - Variance Splitting

# %% [markdown]
# One way to choose features for splitting is *weighted variance*. This criteria is appropriate for **level predictor variables**. Essentially, for each predictor, we compute the variance of the target for each value of the predictor variable then compute the weighted sum of these variances to get the weighted variance for the predictor. We then split the predictor space at each node of the tree by picking the feature with the lowest weighted variance and splitting at the level that minimizes the variance of the target feature.

# %%
print(pd.__version__)
pd.options.mode.copy_on_write = True
# Out:
# 2.1.4

# %%
# subsetting X to only include 5 features of interest
x = X[['season', 'holiday', 'weekday', 'workingday', 'weathersit']]

# appending the target variable to x
x['cnt'] = y
x.head()
# Out:
# C:\Users\benak\AppData\Local\Temp\ipykernel_18552\408793.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['cnt'] = y
#    season  holiday  weekday  workingday  weathersit  cnt
# 0       1        0        6           0           1   16
# 1       1        0        6           0           1   40
# 2       1        0        6           0           1   32
# 3       1        0        6           0           1   13
# 4       1        0        6           0           1    1

# %%
# function to compute feature variances
def var(data, feature, tgt='cnt'):
    feat_vals = np.unique(data[feature])   # unique feature values
    feat_var = 0
    for val in feat_vals:
        subset = data[data[feature] == val]
        # calc weighted var of subsets
        var_val = (len(subset) / len(data)) * np.var(subset[tgt], ddof=1)    # ddof sets degrees of freedom
        # iterate weighted var of feature
        feat_var += var_val
    return feat_var

# %%
var(x, 'season', 'tgt')
# Out:
# 30735.628940122348

# %%
# classifier algorithm
def classifier(data, origData, features,
               minInstances,    # sets minimum number of instances per node as early stopping criteria
               parentNodeClass = None,
               tgt='cnt'):
    # if all target values have same value, return mean of the target
    if len(data) <= int(minInstances):
        return data[tgt].mean()

    # if dataset is empty, return mean of target from the original dataset
    elif len(data) == 0:
        return origData[tgt].mean()

    # if feature space is empty, return mean of target from the direct parent node
    #     - the parent node is the node which called the current run of the function
    elif len(features) == 0:
        return parentNodeClass

    else:
        # set default value for node (i.e. mean of target)
        parentNodeClass = np.mean(data[tgt])
        # select best split feature
        itemVals = [var(data, feature) for feature in features]
        bestFeatIndex = np.argmin(itemVals)    # select min variance feature by index
        bestFeat = features[bestFeatIndex]

        # create tree structure
        tree = {bestFeat:{}}

        # remove the best split feature from the feature space
        features = [i for i in features if i != bestFeat]    # must copy list to preserve features for other levels

        for val in np.unique(data[bestFeat]):
            subData = data[data[bestFeat] == val]    # subset dataset on the minimum variance feature
            subTree = classifier(subData, origData, feats, minInstances, parentNodeClass = parentNodeClass, tgt = tgt)    # recurse Classifier() on the subset to make a new split
            tree[bestFeat][val] = subTree    # add the subTree grown from subData to the root node

        return tree

# %%
tree = classifier(x, x, list(x.columns[:-1]), 5)

# %%
from pprint import pprint
pprint(tree)
# Out:
# {'season': {1: {'weathersit': {1: {'weekday': {0: {'holiday': {0: {'workingday': {0: 104.45232815964523}}}},
#                                                1: {'holiday': {0: {'workingday': {1: 112.53503184713375}},
#                                                                1: {'workingday': {0: 97.62650602409639}}}},
#                                                2: {'holiday': {0: {'workingday': {1: 147.22379603399435}},
#                                                                1: {'workingday': {0: 97.66666666666667}}}},
#                                                3: {'holiday': {0: {'workingday': {1: 124.20056497175142}}}},
#                                                4: {'holiday': {0: {'workingday': {1: 128.58073654390935}}}},
#                                                5: {'holiday': {0: {'workingday': {1: 130.40882352941176}}}},
#                                                6: {'holiday': {0: {'workingday': {0: 117.95620437956204}}}}}},
#                                2: {'workingday': {0: {'weekday': {0: {'holiday': {0: 75.82692307692308}},
#                                                                   1: {'holiday': {1: 49.97826086956522}},
#                                                                   2: {'holiday': {1: 25.875}},
#                                                                   6: {'holiday': {0: 82.61931818181819}}}},
#                                                   1: {'weekday': {1: {'holiday': {0: 121.66115702479338}},
#                                                                   2: {'holiday': {0: 93.88271604938272}},
#                                                                   3: {'holiday': {0: 112.1118881118881}},
#                                                                   4: {'holiday': {0: 143.4939024390244}},
#                                                                   5: {'holiday': {0: 115.95927601809954}}}}}},
#                                3: {'workingday': {0: {'weekday': {0: {'holiday': {0: 40.58064516129032}},
#                                                                   1: {'holiday': {1: 33.333333333333336}},
#                                                                   2: 13.0,
#                                                                   6: {'holiday': {0: 45.327586206896555}}}},
#                                                   1: {'weekday': {1: {'holiday': {0: 78.51428571428572}},
#                                                                   2: {'holiday': {0: 49.121212121212125}},
#                                                                   3: {'holiday': {0: 62.404761904761905}},
#                                                                   4: {'holiday': {0: 56.278688524590166}},
#                                                                   5: {'holiday': {0: 79.5925925925926}}}}}},
#                                4: 74.33333333333333}},
#             2: {'weathersit': {1: {'weekday': {0: {'holiday': {0: {'workingday': {0: 242.8074074074074}}}},
#                                                1: {'holiday': {0: {'workingday': {1: 196.73391812865498}},
#                                                                1: {'workingday': {0: 238.1846153846154}}}},
#                                                2: {'holiday': {0: {'workingday': {1: 237.48395721925132}}}},
#                                                3: {'holiday': {0: {'workingday': {1: 222.78934010152284}}}},
#                                                4: {'holiday': {0: {'workingday': {1: 248.96983758700696}}}},
#                                                5: {'holiday': {0: {'workingday': {1: 235.49308755760367}},
#                                                                1: {'workingday': {0: 120.44444444444444}}}},
#                                                6: {'holiday': {0: {'workingday': {0: 240.11363636363637}}}}}},
#                                2: {'weekday': {0: {'holiday': {0: {'workingday': {0: 161.30769230769232}}}},
#                                                1: {'holiday': {0: {'workingday': {1: 194.92441860465115}},
#                                                                1: {'workingday': {0: 147.0}}}},
#                                                2: {'holiday': {0: {'workingday': {1: 159.45405405405404}}}},
#                                                3: {'holiday': {0: {'workingday': {1: 189.77906976744185}}}},
#                                                4: {'holiday': {0: {'workingday': {1: 149.55263157894737}}}},
#                                                5: {'holiday': {0: {'workingday': {1: 210.95192307692307}},
#                                                                1: {'workingday': {0: 159.66666666666666}}}},
#                                                6: {'holiday': {0: {'workingday': {0: 213.42372881355934}}}}}},
#                                3: {'workingday': {0: {'weekday': {0: {'holiday': {0: 82.6938775510204}},
#                                                                   6: {'holiday': {0: 114.27450980392157}}}},
#                                                   1: {'holiday': {0: {'weekday': {1: 120.5326797385621,
#                                                                                   2: 120.5326797385621,
#                                                                                   3: 120.5326797385621,
#                                                                                   4: 120.5326797385621,
#                                                                                   5: 120.5326797385621}}}}}}}},
#             3: {'weathersit': {1: {'holiday': {0: {'workingday': {0: {'weekday': {0: 242.67780172413794,
#                                                                                   6: 242.67780172413794}},
#                                                                   1: {'weekday': {1: 244.77652173913043,
#                                                                                   2: 244.77652173913043,
#                                                                                   3: 244.77652173913043,
#                                                                                   4: 244.77652173913043,
#                                                                                   5: 244.77652173913043}}}},
#                                                1: {'weekday': {1: {'workingday': {0: 225.17241379310346}},
#                                                                3: {'workingday': {0: 313.9130434782609}}}}}},
#                                2: {'weekday': {0: {'holiday': {0: {'workingday': {0: 172.77659574468086}}}},
#                                                1: {'holiday': {0: {'workingday': {1: 210.984}},
#                                                                1: {'workingday': {0: 217.15384615384616}}}},
#                                                2: {'holiday': {0: {'workingday': {1: 242.648}}}},
#                                                3: {'holiday': {0: {'workingday': {1: 232.0810810810811}},
#                                                                1: 183.0}},
#                                                4: {'holiday': {0: {'workingday': {1: 199.78787878787878}}}},
#                                                5: {'holiday': {0: {'workingday': {1: 281.25142857142856}}}},
#                                                6: {'holiday': {0: {'workingday': {0: 206.7793103448276}}}}}},
#                                3: {'weekday': {0: {'holiday': {0: {'workingday': {0: 201.02380952380952}}}},
#                                                1: {'holiday': {0: {'workingday': {1: 138.47619047619048}},
#                                                                1: 107.25}},
#                                                2: {'holiday': {0: {'workingday': {1: 188.51063829787233}}}},
#                                                3: {'holiday': {0: {'workingday': {1: 195.29268292682926}}}},
#                                                4: {'holiday': {0: {'workingday': {1: 136.51612903225808}}}},
#                                                5: {'holiday': {0: {'workingday': {1: 121.93939393939394}}}},
#                                                6: {'holiday': {0: {'workingday': {0: 187.06}}}}}}}},
#             4: {'weathersit': {1: {'holiday': {0: {'weekday': {0: {'workingday': {0: 197.19859813084113}},
#                                                                1: {'workingday': {1: 202.66555183946488}},
#                                                                2: {'workingday': {1: 229.56050955414014}},
#                                                                3: {'workingday': {1: 222.80307692307693}},
#                                                                4: {'workingday': {1: 219.20253164556962}},
#                                                                5: {'workingday': {1: 203.6452442159383}},
#                                                                6: {'workingday': {0: 220.09026128266032}}}},
#                                                1: {'weekday': {1: {'workingday': {0: 190.4}},
#                                                                4: {'workingday': {0: 81.66666666666667}},
#                                                                5: {'workingday': {0: 140.33333333333334}}}}}},
#                                2: {'holiday': {0: {'weekday': {0: {'workingday': {0: 170.64429530201343}},
#                                                                1: {'workingday': {1: 197.96391752577318}},
#                                                                2: {'workingday': {1: 188.63106796116506}},
#                                                                3: {'workingday': {1: 207.06451612903226}},
#                                                                4: {'workingday': {1: 209.8404255319149}},
#                                                                5: {'workingday': {1: 230.23529411764707}},
#                                                                6: {'workingday': {0: 190.08666666666667}}}},
#                                                1: {'weekday': {1: {'workingday': {0: 320.90909090909093}}}}}},
#                                3: {'weekday': {0: {'holiday': {0: {'workingday': {0: 126.04255319148936}}}},
#                                                1: {'holiday': {0: {'workingday': {1: 180.11428571428573}},
#                                                                1: 247.2}},
#                                                2: {'holiday': {0: {'workingday': {1: 112.0}}}},
#                                                3: {'holiday': {0: {'workingday': {1: 93.69318181818181}}}},
#                                                4: {'holiday': {0: {'workingday': {1: 122.47826086956522}}}},
#                                                5: {'holiday': {0: {'workingday': {1: 136.91176470588235}}}},
#                                                6: {'holiday': {0: {'workingday': {0: 51.03448275862069}}}}}}}}}}

# %% [markdown]
# ## Regresseion Tree on Continuous Variables

# %%
# fetch dataset 
heart_disease = fetch_ucirepo(id=45) 
  
# data (as pandas dataframes) 
X = heart_disease.data.features 
y = heart_disease.data.targets 

# variable information 
print(heart_disease.variables) 


feats = ['age', 'trestbps', 'chol']    # list of features

df = X[feats]
df['num'] = y
# Out:
#         name     role         type demographic  \
# 0        age  Feature      Integer         Age
# 1        sex  Feature  Categorical         Sex
# 2         cp  Feature  Categorical        None
# 3   trestbps  Feature      Integer        None
# 4       chol  Feature      Integer        None
# 5        fbs  Feature  Categorical        None
# 6    restecg  Feature  Categorical        None
# 7    thalach  Feature      Integer        None
# 8      exang  Feature  Categorical        None
# 9    oldpeak  Feature      Integer        None
# 10     slope  Feature  Categorical        None
# 11        ca  Feature      Integer        None
# 12      thal  Feature  Categorical        None
# 13       num   Target      Integer        None
#
#                                           description  units missing_values
# 0                                                None  years             no
# 1                                                None   None             no
# 2                                                None   None             no
# 3   resting blood pressure (on admission to the ho...  mm Hg             no
# 4                                   serum cholestoral  mg/dl             no
# 5                     fasting blood sugar > 120 mg/dl   None             no
# 6                                                None   None             no
# 7                         maximum heart rate achieved   None             no
# 8                             exercise induced angina   None             no
# 9   ST depression induced by exercise relative to ...   None             no
# 10                                               None   None             no
# 11  number of major vessels (0-3) colored by flour...   None            yes
# 12                                               None   None            yes
# 13                         diagnosis of heart disease   None             no
# C:\Users\benak\AppData\Local\Temp\ipykernel_18552\1471341705.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['num'] = y

# %%
def rmse(data, val, feat, tgt):
    lhs = data[data[feat] <= val][tgt]
    rhs = data[data[feat] > val][tgt]

    lhs_pred = lhs.mean()
    rhs_pred = rhs.mean()

    residuals = []
    for obs in lhs: residuals.append((obs - lhs_pred)**2)
    for obs in rhs: residuals.append((obs - rhs_pred)**2)

    return np.sqrt(np.sum(residuals) / len(residuals))

# %%
rmse(50, 'age', df, 'num')
# Out:
# 1.204928034421781

# %%
def branch(data, feats, tgt, pNodeClass=None, minInstances=None, tier=0, maxDepth=None):
    print(f'Tier: {tier}, Features: {feats}')
    pred = data[tgt].mean()

    if pNodeClass is None: 
        pNodeClass = pred
    elif pred == pNodeClass:
        return pNodeClass

    if tier == maxDepth: return pred
    
    if len(data) <= int(minInstances):
        return pred
    else:
        tier += 1
        splits = dict((feat, '') for feat in feats)
        for feat in feats:
            minErr = 0
            for i in range(len(data[feat]) - 1):
                val = (data[feat].iloc[i] + data[feat].iloc[i+1])/2    # midpoint

                try:
                    err = rmse(data, val, feat, tgt)
                    pass
                except ValueError:
                    print(f'{feat}: {data[feat].iloc[i]}')
                    
                if minErr == 0 or err < minErr:
                    minErr = err
                    splits[feat] = (val, minErr)

        bestFeat = feats[np.argmin([splits[feat][1] for feat in feats])]    # minimum rmse feature
        bestSplit = splits[bestFeat][0]
        node = (bestFeat, bestSplit)

        print(splits)
        print(node)
        
        lhs = data[data[bestFeat] < bestSplit]
        lhs = branch(lhs, feats, tgt, pred, minInstances, tier, maxDepth)
        
        rhs = data[data[bestFeat] > bestSplit]
        rhs = branch(rhs, feats, tgt, pred, minInstances, tier, maxDepth)

        tree = {node:{}}
        tree[node] = (lhs, rhs)

        return tree

# %%
tree = branch(df, feats, 'num', minInstances=5, maxDepth=None)
# Out:
# Tier: 0, Features: ['age', 'trestbps', 'chol']
# {'age': (54.5, 1.1846860027094008), 'trestbps': (142.5, 1.208213493978743), 'chol': (279.5, 1.2116188917910682)}
# ('age', 54.5)
# Tier: 1, Features: ['age', 'trestbps', 'chol']
# {'age': (47.0, 1.0459306530691959), 'trestbps': (108.5, 1.0389146900443207), 'chol': (272.0, 1.032682703657598)}
# ('chol', 272.0)
# Tier: 2, Features: ['age', 'trestbps', 'chol']
# {'age': (53.0, 0.9856254308197118), 'trestbps': (128.0, 0.9790332759914939), 'chol': (188.0, 0.9804185414512698)}
# ('trestbps', 128.0)
# Tier: 3, Features: ['age', 'trestbps', 'chol']
# {'age': (51.5, 1.0567221484178237), 'trestbps': (109.0, 1.0515194229831875), 'chol': (239.0, 1.0575095584461456)}
# ('trestbps', 109.0)
# Tier: 4, Features: ['age', 'trestbps', 'chol']
# {'age': (46.5, 0.25819888974716115), 'trestbps': (106.0, 0.25), 'chol': (235.0, 0.23570226039551584)}
# ('chol', 235.0)
# Tier: 5, Features: ['age', 'trestbps', 'chol']
# {'age': (42.5, 0.0), 'trestbps': (99.5, 0.0), 'chol': (201.5, 0.0)}
# ('age', 42.5)
# Tier: 6, Features: ['age', 'trestbps', 'chol']
# Tier: 6, Features: ['age', 'trestbps', 'chol']
# Tier: 5, Features: ['age', 'trestbps', 'chol']
# Tier: 4, Features: ['age', 'trestbps', 'chol']
# {'age': (51.0, 1.1211985407591527), 'trestbps': (111.0, 1.1519705811753018), 'chol': (239.0, 1.10985513723908)}
# ('chol', 239.0)
# Tier: 5, Features: ['age', 'trestbps', 'chol']
# {'age': (37.5, 1.2206804872393833), 'trestbps': (120.0, 1.2508820417421225), 'chol': (230.5, 1.2307338795828044)}
# ('age', 37.5)
# Tier: 6, Features: ['age', 'trestbps', 'chol']
# Tier: 6, Features: ['age', 'trestbps', 'chol']
# {'age': (40.5, 1.061961883287788), 'trestbps': (115.0, 1.296221168283466), 'chol': (230.5, 1.2865350418053538)}
# ('age', 40.5)
# Tier: 7, Features: ['age', 'trestbps', 'chol']
# Tier: 7, Features: ['age', 'trestbps', 'chol']
# {'age': (51.5, 1.0432936012750862), 'trestbps': (122.5, 1.0919284281983377), 'chol': (213.5, 1.0459527207369814)}
# ('age', 51.5)
# Tier: 8, Features: ['age', 'trestbps', 'chol']
# {'age': (49.0, 0.9362000791686007), 'trestbps': (120.0, 0.9362000791686007), 'chol': (198.0, 0.7894506464829344)}
# ('chol', 198.0)
# Tier: 9, Features: ['age', 'trestbps', 'chol']
# {'age': (42.5, 1.0653265391046234), 'trestbps': (119.0, 0.8944271909999159), 'chol': (176.0, 0.816496580927726)}
# ('chol', 176.0)
# Tier: 10, Features: ['age', 'trestbps', 'chol']
# {'age': (46.0, 0.7359800721939872), 'trestbps': (115.0, 0.6666666666666667), 'chol': (166.0, 0.6666666666666667)}
# ('trestbps', 115.0)
# Tier: 11, Features: ['age', 'trestbps', 'chol']
# Tier: 11, Features: ['age', 'trestbps', 'chol']
# Tier: 10, Features: ['age', 'trestbps', 'chol']
# Tier: 9, Features: ['age', 'trestbps', 'chol']
# {'age': (46.0, 0.2696799449852969), 'trestbps': (111.0, 0.24618298195866548), 'chol': (224.0, 0.24618298195866548)}
# ('trestbps', 111.0)
# Tier: 10, Features: ['age', 'trestbps', 'chol']
# Tier: 10, Features: ['age', 'trestbps', 'chol']
# {'age': (43.0, 0.0), 'trestbps': (120.0, 0.0), 'chol': (217.5, 0.0)}
# ('age', 43.0)
# Tier: 11, Features: ['age', 'trestbps', 'chol']
# Tier: 11, Features: ['age', 'trestbps', 'chol']
# Tier: 8, Features: ['age', 'trestbps', 'chol']
# {'age': (53.0, 1.247219128924647), 'trestbps': (119.0, 1.0408329997330663), 'chol': (187.0, 1.0645812948447542)}
# ('trestbps', 119.0)
# Tier: 9, Features: ['age', 'trestbps', 'chol']
# Tier: 9, Features: ['age', 'trestbps', 'chol']
# Tier: 5, Features: ['age', 'trestbps', 'chol']
# {'age': (44.5, 0.37796447300922725), 'trestbps': (111.0, 0.39339789623472154), 'chol': (263.0, 0.33549085316013094)}
# ('chol', 263.0)
# Tier: 6, Features: ['age', 'trestbps', 'chol']
# {'age': (46.0, 0.28284271247461906), 'trestbps': (118.5, 0.2886751345948129), 'chol': (249.0, 0.28284271247461906)}
# ('age', 46.0)
# Tier: 7, Features: ['age', 'trestbps', 'chol']
# Tier: 7, Features: ['age', 'trestbps', 'chol']
# Tier: 6, Features: ['age', 'trestbps', 'chol']
# Tier: 3, Features: ['age', 'trestbps', 'chol']
# {'age': (47.0, 0.8161632489763258), 'trestbps': (140.0, 0.7913949865915663), 'chol': (198.5, 0.8286066143127261)}
# ('trestbps', 140.0)
# Tier: 4, Features: ['age', 'trestbps', 'chol']
# {'age': (48.5, 0.5435218112026151), 'trestbps': (132.0, 0.5435218112026151), 'chol': (245.5, 0.5250331647114501)}
# ('chol', 245.5)
# Tier: 5, Features: ['age', 'trestbps', 'chol']
# {'age': (38.5, 0.0), 'trestbps': (138.0, 0.0), 'chol': (197.5, 0.0)}
# ('age', 38.5)
# Tier: 6, Features: ['age', 'trestbps', 'chol']
# Tier: 6, Features: ['age', 'trestbps', 'chol']
# Tier: 5, Features: ['age', 'trestbps', 'chol']
# {'age': (48.0, 0.7862453931068966), 'trestbps': (133.0, 0.864566219253764), 'chol': (256.5, 0.816496580927726)}
# ('age', 48.0)
# Tier: 6, Features: ['age', 'trestbps', 'chol']
# Tier: 6, Features: ['age', 'trestbps', 'chol']
# {'age': (49.0, 0.0), 'trestbps': (132.0, 0.0), 'chol': (270.0, 0.0)}
# ('age', 49.0)
# Tier: 7, Features: ['age', 'trestbps', 'chol']
# Tier: 7, Features: ['age', 'trestbps', 'chol']
# Tier: 4, Features: ['age', 'trestbps', 'chol']
# {'age': (50.0, 1.1843130509275843), 'trestbps': (152.0, 1.2792042981336627), 'chol': (235.0, 1.2983089234100107)}
# ('age', 50.0)
# Tier: 5, Features: ['age', 'trestbps', 'chol']
# Tier: 5, Features: ['age', 'trestbps', 'chol']
# Tier: 2, Features: ['age', 'trestbps', 'chol']
# {'age': (41.5, 1.152401099246931), 'trestbps': (121.0, 1.12934239313482), 'chol': (293.5, 1.1380245245651768)}
# ('trestbps', 121.0)
# Tier: 3, Features: ['age', 'trestbps', 'chol']
# {'age': (48.0, 0.6267831705280087), 'trestbps': (114.0, 0.5345224838248488), 'chol': (302.0, 0.6267831705280087)}
# ('trestbps', 114.0)
# Tier: 4, Features: ['age', 'trestbps', 'chol']
# Tier: 4, Features: ['age', 'trestbps', 'chol']
# Tier: 3, Features: ['age', 'trestbps', 'chol']
# {'age': (41.0, 1.182676660349146), 'trestbps': (124.0, 0.9952038092820834), 'chol': (298.5, 1.2135597524338357)}
# ('trestbps', 124.0)
# Tier: 4, Features: ['age', 'trestbps', 'chol']
# Tier: 4, Features: ['age', 'trestbps', 'chol']
# {'age': (51.0, 0.9871352947927471), 'trestbps': (130.0, 1.009975309259233), 'chol': (289.0, 1.0292708565973299)}
# ('age', 51.0)
# Tier: 5, Features: ['age', 'trestbps', 'chol']
# {'age': (41.0, 1.004750620564033), 'trestbps': (130.0, 0.7483314773547882), 'chol': (307.5, 1.004750620564033)}
# ('trestbps', 130.0)
# Tier: 6, Features: ['age', 'trestbps', 'chol']
# Tier: 6, Features: ['age', 'trestbps', 'chol']
# Tier: 5, Features: ['age', 'trestbps', 'chol']
# Tier: 1, Features: ['age', 'trestbps', 'chol']
# {'age': (63.0, 1.2871498793911103), 'trestbps': (158.0, 1.2780275781992707), 'chol': (176.5, 1.2755932572316055)}
# ('chol', 176.5)
# Tier: 2, Features: ['age', 'trestbps', 'chol']
# {'age': (58.0, 1.449137674618944), 'trestbps': (125.0, 1.4880476182856899), 'chol': (150.0, 1.449137674618944)}
# ('age', 58.0)
# Tier: 3, Features: ['age', 'trestbps', 'chol']
# Tier: 3, Features: ['age', 'trestbps', 'chol']
# Tier: 2, Features: ['age', 'trestbps', 'chol']
# {'age': (63.0, 1.2456257607387387), 'trestbps': (162.5, 1.239144593382173), 'chol': (253.5, 1.2331622189200193)}
# ('chol', 253.5)
# Tier: 3, Features: ['age', 'trestbps', 'chol']
# {'age': (68.5, 1.1520862083971612), 'trestbps': (110.0, 1.1687610200470515), 'chol': (230.0, 1.1613286401903278)}
# ('age', 68.5)
# Tier: 4, Features: ['age', 'trestbps', 'chol']
# {'age': (63.0, 1.1665564321819242), 'trestbps': (110.0, 1.174453182454617), 'chol': (201.5, 1.1722409823748232)}
# ('age', 63.0)
# Tier: 5, Features: ['age', 'trestbps', 'chol']
# {'age': (61.0, 1.0854114030321405), 'trestbps': (119.0, 1.0890835654960664), 'chol': (239.0, 1.0719638671919773)}
# ('chol', 239.0)
# Tier: 6, Features: ['age', 'trestbps', 'chol']
# {'age': (61.0, 1.1501019516569335), 'trestbps': (119.0, 1.150437014140854), 'chol': (201.0, 1.154431471490272)}
# ('age', 61.0)
# Tier: 7, Features: ['age', 'trestbps', 'chol']
# {'age': (59.0, 1.214335912539309), 'trestbps': (132.0, 1.226072633655704), 'chol': (203.0, 1.1807240985575105)}
# ('chol', 203.0)
# Tier: 8, Features: ['age', 'trestbps', 'chol']
# {'age': (58.5, 0.5916079783099616), 'trestbps': (136.0, 0.5916079783099616), 'chol': (188.5, 0.5)}
# ('chol', 188.5)
# Tier: 9, Features: ['age', 'trestbps', 'chol']
# Tier: 9, Features: ['age', 'trestbps', 'chol']
# Tier: 8, Features: ['age', 'trestbps', 'chol']
# {'age': (59.0, 1.2021375027713586), 'trestbps': (116.0, 1.2021375027713586), 'chol': (230.0, 1.2734752178329904)}
# ('age', 59.0)
# Tier: 9, Features: ['age', 'trestbps', 'chol']
# {'age': (57.0, 1.243734296383275), 'trestbps': (116.0, 1.1100193048514322), 'chol': (223.0, 1.2119199643540823)}
# ('trestbps', 116.0)
# Tier: 10, Features: ['age', 'trestbps', 'chol']
# Tier: 10, Features: ['age', 'trestbps', 'chol']
# {'age': (56.5, 1.1019463300386794), 'trestbps': (126.0, 1.023532631438318), 'chol': (230.0, 1.0970247050377686)}
# ('trestbps', 126.0)
# Tier: 11, Features: ['age', 'trestbps', 'chol']
# Tier: 11, Features: ['age', 'trestbps', 'chol']
# {'age': (56.5, 1.0363754503432017), 'trestbps': (128.0, 1.0886621079036347), 'chol': (222.5, 1.0823255385643318)}
# ('age', 56.5)
# Tier: 12, Features: ['age', 'trestbps', 'chol']
# Tier: 12, Features: ['age', 'trestbps', 'chol']
# {'age': (57.5, 0.8130873945100312), 'trestbps': (162.0, 0.816496580927726), 'chol': (212.5, 0.642416074439621)}
# ('chol', 212.5)
# Tier: 13, Features: ['age', 'trestbps', 'chol']
# Tier: 13, Features: ['age', 'trestbps', 'chol']
# {'age': (57.5, 0.6267831705280087), 'trestbps': (130.0, 0.6267831705280087), 'chol': (225.0, 0.6267831705280087)}
# ('age', 57.5)
# Tier: 14, Features: ['age', 'trestbps', 'chol']
# Tier: 14, Features: ['age', 'trestbps', 'chol']
# Tier: 9, Features: ['age', 'trestbps', 'chol']
# Tier: 7, Features: ['age', 'trestbps', 'chol']
# Tier: 6, Features: ['age', 'trestbps', 'chol']
# {'age': (61.0, 0.46709936649691375), 'trestbps': (120.0, 0.41286141192238524), 'chol': (240.0, 0.41286141192238524)}
# ('trestbps', 120.0)
# Tier: 7, Features: ['age', 'trestbps', 'chol']
# Tier: 7, Features: ['age', 'trestbps', 'chol']
# {'age': (55.5, 0.4225771273642583), 'trestbps': (130.0, 0.4330127018922193), 'chol': (240.5, 0.4225771273642583)}
# ('age', 55.5)
# Tier: 8, Features: ['age', 'trestbps', 'chol']
# Tier: 8, Features: ['age', 'trestbps', 'chol']
# {'age': (58.0, 0.41403933560541256), 'trestbps': (140.0, 0.3779644730092272), 'chol': (240.5, 0.3450327796711771)}
# ('chol', 240.5)
# Tier: 9, Features: ['age', 'trestbps', 'chol']
# Tier: 9, Features: ['age', 'trestbps', 'chol']
# {'age': (60.5, 0.28867513459481287), 'trestbps': (140.0, 0.33333333333333337), 'chol': (248.0, 0.33333333333333337)}
# ('age', 60.5)
# Tier: 10, Features: ['age', 'trestbps', 'chol']
# Tier: 10, Features: ['age', 'trestbps', 'chol']
# Tier: 5, Features: ['age', 'trestbps', 'chol']
# {'age': (66.0, 1.3522957160708984), 'trestbps': (130.0, 1.3240416986458872), 'chol': (229.0, 1.340753164314389)}
# ('trestbps', 130.0)
# Tier: 6, Features: ['age', 'trestbps', 'chol']
# {'age': (67.0, 0.9930312739844155), 'trestbps': (115.0, 1.0301024760241628), 'chol': (211.5, 0.7817359599705717)}
# ('chol', 211.5)
# Tier: 7, Features: ['age', 'trestbps', 'chol']
# Tier: 7, Features: ['age', 'trestbps', 'chol']
# {'age': (64.5, 0.6831300510639733), 'trestbps': (115.0, 0.816496580927726), 'chol': (229.0, 0.816496580927726)}
# ('age', 64.5)
# Tier: 8, Features: ['age', 'trestbps', 'chol']
# Tier: 8, Features: ['age', 'trestbps', 'chol']
# Tier: 6, Features: ['age', 'trestbps', 'chol']
# {'age': (65.5, 1.4142135623730951), 'trestbps': (147.5, 1.4029447488244033), 'chol': (225.5, 1.2801909579781015)}
# ('chol', 225.5)
# Tier: 7, Features: ['age', 'trestbps', 'chol']
# Tier: 7, Features: ['age', 'trestbps', 'chol']
# Tier: 4, Features: ['age', 'trestbps', 'chol']
# Tier: 3, Features: ['age', 'trestbps', 'chol']
# {'age': (63.0, 1.2478967466617568), 'trestbps': (120.0, 1.2769249315060593), 'chol': (260.5, 1.2521954186551032)}
# ('age', 63.0)
# Tier: 4, Features: ['age', 'trestbps', 'chol']
# {'age': (58.0, 1.2132600710482482), 'trestbps': (159.0, 1.1921603274082921), 'chol': (339.5, 1.1879019787470306)}
# ('chol', 339.5)
# Tier: 5, Features: ['age', 'trestbps', 'chol']
# {'age': (61.0, 1.166138643708339), 'trestbps': (159.0, 1.1608177859489195), 'chol': (260.5, 1.1661386437083392)}
# ('trestbps', 159.0)
# Tier: 6, Features: ['age', 'trestbps', 'chol']
# {'age': (57.0, 1.045167626062401), 'trestbps': (122.5, 1.0897687856350051), 'chol': (260.5, 1.0647755154317868)}
# ('age', 57.0)
# Tier: 7, Features: ['age', 'trestbps', 'chol']
# Tier: 7, Features: ['age', 'trestbps', 'chol']
# {'age': (58.0, 1.0966300208353785), 'trestbps': (111.0, 1.0568269096134508), 'chol': (264.0, 1.101287530392917)}
# ('trestbps', 111.0)
# Tier: 8, Features: ['age', 'trestbps', 'chol']
# Tier: 8, Features: ['age', 'trestbps', 'chol']
# {'age': (58.0, 1.0626625525914952), 'trestbps': (122.5, 1.0645812948447542), 'chol': (307.0, 1.0299740583366948)}
# ('chol', 307.0)
# Tier: 9, Features: ['age', 'trestbps', 'chol']
# {'age': (59.0, 0.9497161598676341), 'trestbps': (125.0, 0.9824666109905364), 'chol': (264.0, 0.9615143285055968)}
# ('age', 59.0)
# Tier: 10, Features: ['age', 'trestbps', 'chol']
# Tier: 10, Features: ['age', 'trestbps', 'chol']
# {'age': (60.0, 0.7156264473321343), 'trestbps': (125.0, 0.7139609651376325), 'chol': (299.0, 0.6674238124719145)}
# ('chol', 299.0)
# Tier: 11, Features: ['age', 'trestbps', 'chol']
# {'age': (61.0, 0.6928203230275509), 'trestbps': (139.0, 0.6191391873668903), 'chol': (275.0, 0.689202437604511)}
# ('trestbps', 139.0)
# Tier: 12, Features: ['age', 'trestbps', 'chol']
# {'age': (60.5, 0.5773502691896257), 'trestbps': (122.5, 0.6666666666666667), 'chol': (272.0, 0.5)}
# ('chol', 272.0)
# Tier: 13, Features: ['age', 'trestbps', 'chol']
# Tier: 13, Features: ['age', 'trestbps', 'chol']
# Tier: 12, Features: ['age', 'trestbps', 'chol']
# Tier: 11, Features: ['age', 'trestbps', 'chol']
# Tier: 9, Features: ['age', 'trestbps', 'chol']
# Tier: 6, Features: ['age', 'trestbps', 'chol']
# {'age': (57.5, 0.770551750371122), 'trestbps': (167.5, 1.1832159566199232), 'chol': (279.5, 0.9895285072531598)}
# ('age', 57.5)
# Tier: 7, Features: ['age', 'trestbps', 'chol']
# Tier: 7, Features: ['age', 'trestbps', 'chol']
# Tier: 5, Features: ['age', 'trestbps', 'chol']
# {'age': (56.5, 0.8819171036881969), 'trestbps': (120.0, 1.0606601717798212), 'chol': (347.0, 1.0606601717798212)}
# ('age', 56.5)
# Tier: 6, Features: ['age', 'trestbps', 'chol']
# Tier: 6, Features: ['age', 'trestbps', 'chol']
# Tier: 4, Features: ['age', 'trestbps', 'chol']
# {'age': (66.0, 1.1316478165165966), 'trestbps': (122.5, 1.2369245584576678), 'chol': (261.5, 1.1646808496242573)}
# ('age', 66.0)
# Tier: 5, Features: ['age', 'trestbps', 'chol']
# {'age': (64.5, 0.6419666752419568), 'trestbps': (140.0, 0.5935256753272998), 'chol': (268.0, 0.6030226891555273)}
# ('trestbps', 140.0)
# Tier: 6, Features: ['age', 'trestbps', 'chol']
# Tier: 6, Features: ['age', 'trestbps', 'chol']
# Tier: 5, Features: ['age', 'trestbps', 'chol']
# {'age': (70.5, 1.4167366929471605), 'trestbps': (122.5, 1.2873006086935783), 'chol': (414.5, 1.3907069907302307)}
# ('trestbps', 122.5)
# Tier: 6, Features: ['age', 'trestbps', 'chol']
# Tier: 6, Features: ['age', 'trestbps', 'chol']
# {'age': (73.5, 1.130388330520878), 'trestbps': (127.5, 1.0653265391046236), 'chol': (313.0, 1.2856040517117926)}
# ('trestbps', 127.5)
# Tier: 7, Features: ['age', 'trestbps', 'chol']
# Tier: 7, Features: ['age', 'trestbps', 'chol']
# {'age': (70.0, 0.9880235200593537), 'trestbps': (160.0, 1.023532631438318), 'chol': (294.0, 0.9636241116594315)}
# ('chol', 294.0)
# Tier: 8, Features: ['age', 'trestbps', 'chol']
# Tier: 8, Features: ['age', 'trestbps', 'chol']

# %%
pprint(tree)
# Out:
# {('age', 54.5): ({('chol', 272.0): ({('trestbps', 128.0): ({('trestbps', 109.0): ({('chol', 235.0): ({('age', 42.5): (0.0,
#                                                                                                                       0.0)},
#                                                                                                      0.3333333333333333)},
#                                                                                   {('chol', 239.0): ({('age', 37.5): (0.2,
#                                                                                                                       {('age', 40.5): (3.3333333333333335,
#                                                                                                                                        {('age', 51.5): ({('chol', 198.0): ({('chol', 176.0): ({('trestbps', 115.0): (0.3333333333333333,
#                                                                                                                                                                                                                      1.0)},
#                                                                                                                                                                                               2.3333333333333335)},
#                                                                                                                                                                            {('trestbps', 111.0): (0.3333333333333333,
#                                                                                                                                                                                                   {('age', 43.0): (0.0,
#                                                                                                                                                                                                                    0.0)})})},
#                                                                                                                                                         {('trestbps', 119.0): (1.0,
#                                                                                                                                                                                2.5)})})})},
#                                                                                                      {('chol', 263.0): ({('age', 46.0): (0.0,
#                                                                                                                                          0.0)},
#                                                                                                                         0.6666666666666666)})})},
#                                                            {('trestbps', 140.0): ({('chol', 245.5): ({('age', 38.5): (0.0,
#                                                                                                                       0.0)},
#                                                                                                      {('age', 48.0): (0.25,
#                                                                                                                       {('age', 49.0): (nan,
#                                                                                                                                        0.0)})})},
#                                                                                   {('age', 50.0): (0.4,
#                                                                                                    0.0)})})},
#                                     {('trestbps', 121.0): ({('trestbps', 114.0): (1.0,
#                                                                                   0.0)},
#                                                            {('trestbps', 124.0): (3.0,
#                                                                                   {('age', 51.0): ({('trestbps', 130.0): (0.3333333333333333,
#                                                                                                                           1.8)},
#                                                                                                    0.2)})})})},
#                  {('chol', 176.5): ({('age', 58.0): (1.0, 2.8)},
#                                     {('chol', 253.5): ({('age', 68.5): ({('age', 63.0): ({('chol', 239.0): ({('age', 61.0): ({('chol', 203.0): ({('chol', 188.5): (1.0,
#                                                                                                                                                                    0.0)},
#                                                                                                                                                 {('age', 59.0): ({('trestbps', 116.0): (3.0,
#                                                                                                                                                                                         {('trestbps', 126.0): (0.0,
#                                                                                                                                                                                                                {('age', 56.5): (2.0,
#                                                                                                                                                                                                                                 {('chol', 212.5): (0.0,
#                                                                                                                                                                                                                                                    {('age', 57.5): (1.0,
#                                                                                                                                                                                                                                                                     1.75)})})})})},
#                                                                                                                                                                  3.0)})},
#                                                                                                                              0.0)},
#                                                                                                             {('trestbps', 120.0): (0.0,
#                                                                                                                                    {('age', 55.5): (0.0,
#                                                                                                                                                     {('chol', 240.5): (0.0,
#                                                                                                                                                                        {('age', 60.5): (1.0,
#                                                                                                                                                                                         0.5)})})})})},
#                                                                                          {('trestbps', 130.0): ({('chol', 211.5): (0.0,
#                                                                                                                                    {('age', 64.5): (3.0,
#                                                                                                                                                     1.2)})},
#                                                                                                                 {('chol', 225.5): (2.75,
#                                                                                                                                    1.0)})})},
#                                                                         0.0)},
#                                                        {('age', 63.0): ({('chol', 339.5): ({('trestbps', 159.0): ({('age', 57.0): (1.0,
#                                                                                                                                    {('trestbps', 111.0): (0.0,
#                                                                                                                                                           {('chol', 307.0): ({('age', 59.0): (1.6,
#                                                                                                                                                                                               {('chol', 299.0): ({('trestbps', 139.0): ({('chol', 272.0): (1.5,
#                                                                                                                                                                                                                                                            2.5)},
#                                                                                                                                                                                                                                         2.5)},
#                                                                                                                                                                                                                  1.0)})},
#                                                                                                                                                                              2.6666666666666665)})})},
#                                                                                                                   {('age', 57.5): (3.25,
#                                                                                                                                    1.0)})},
#                                                                                            {('age', 56.5): (1.6666666666666667,
#                                                                                                             0.0)})},
#                                                                         {('age', 66.0): ({('trestbps', 140.0): (0.8,
#                                                                                                                 0.0)},
#                                                                                          {('trestbps', 122.5): (0.6,
#                                                                                                                 {('trestbps', 127.5): (3.5,
#                                                                                                                                        {('chol', 294.0): (2.0,
#                                                                                                                                                           0.5)})})})})})})})}
